# %%
import sys
import pandas as pd
import numpy as np
import sklearn

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("interpreter:", sys.executable)
# Out:
# Python: 3.11.1
# pandas: 3.0.5
# numpy: 2.4.6
# scikit-learn: 1.9.1
# interpreter: d:\Flow1A\.venv\Scripts\python.exe
